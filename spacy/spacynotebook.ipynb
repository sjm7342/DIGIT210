# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.2.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.12-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.11-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.5 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.9-cp313-cp313-macosx_15_0_arm64.whl
# Collecting thinc<8.4.0,>=8.3.0 (from spacy)
#   Using cached thinc-8.3.6-cp313-cp313-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Using cached srsly-2.5.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Using cached typer-0.15.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from spacy) (4.67.1)
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.2.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from spacy) (2.32.3)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Using cached pydantic-2.11.3-py3-none-any.whl.metadata (65 kB)
# Requirement already satisfied: jinja2 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from spacy) (78.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from spacy) (24.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Using cached langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.1 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached pydantic_core-2.33.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.1)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/opt/certifi/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.0->spacy)
#   Using cached blis-1.3.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.0->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached cloudpathlib-0.21.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from jinja2->spacy) (3.0.2)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Downloading wrapt-1.17.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.11-cp313-cp313-macosx_11_0_arm64.whl (41 kB)
# Using cached langcodes-3.5.0-py3-none-any.whl (182 kB)
# Using cached murmurhash-1.0.12-cp313-cp313-macosx_11_0_arm64.whl (26 kB)
# Downloading numpy-2.2.4-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 44.5 MB/s eta 0:00:00
# Using cached pydantic-2.11.3-py3-none-any.whl (443 kB)
# Using cached pydantic_core-2.33.1-cp313-cp313-macosx_11_0_arm64.whl (1.9 MB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.5.1-cp313-cp313-macosx_11_0_arm64.whl (632 kB)
# Using cached thinc-8.3.6-cp313-cp313-macosx_11_0_arm64.whl (832 kB)
# Using cached typer-0.15.2-py3-none-any.whl (45 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached blis-1.3.0-cp313-cp313-macosx_11_0_arm64.whl (1.3 MB)
# Using cached cloudpathlib-0.21.0-py3-none-any.whl (52 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached smart_open-7.1.0-py3-none-any.whl (61 kB)
# Using cached typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading marisa_trie-1.2.1-cp313-cp313-macosx_11_0_arm64.whl (171 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading wrapt-1.17.2-cp313-cp313-macosx_11_0_arm64.whl (38 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: spacy
#   Building wheel for spacy (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for spacy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1485 lines of output]
#       Copied /private/var/folders/8k/h6dlr8g14r1952jl8tmfcpc40000gn/T/pip-install-cu5wge2g/spacy_e65814699b3146ba80b7ba2a503edab1/setup.cfg -> /private/var/folders/8k/h6dlr8g14r1952jl8tmfcpc40000gn/T/pip-install-cu5wge2g/spacy_e65814699b3146ba80b7ba2a503edab1/spacy/tests/package
#       Copied /private/var/folders/8k/h6dlr8g14r1952jl8tmfcpc40000gn/T/pip-install-cu5wge2g/spacy_e65814699b3146ba80b7ba2a503edab1/pyproject.toml -> /private/var/folders/8k/h6dlr8g14r1952jl8tmfcpc40000gn/T/pip-install-cu5wge2g/spacy_e65814699b3146ba80b7ba2a503edab1/spacy/tests/package
#       Cythonizing sources
#       /private/var/folders/8k/h6dlr8g14r1952jl8tmfcpc40000gn/T/pip-build-env-lzxe3io4/overlay/lib/python3.13/site-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/git_info.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/compat.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/util.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/lookups.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/about.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/schemas.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/language.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/pipe_analysis.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/errors.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/ty.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/__main__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/scorer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/glossary.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/displacy
#       copying spacy/displacy/render.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/displacy
#       copying spacy/displacy/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/displacy
#       copying spacy/displacy/templates.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/displacy
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/functions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/tok2vec.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/lemmatizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/edit_tree_lemmatizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/entityruler.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/spancat.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/attributeruler.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/span_ruler.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/entity_linker.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/textcat_multilabel.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/span_finder.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/textcat.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/kb
#       copying spacy/kb/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/kb
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/pretrain.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/initialize.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/alignment.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/loggers.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/batchers.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/augment.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/iob_utils.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/callbacks.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/loop.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/corpus.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_displacy.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/tok2vec.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/conftest.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_misc.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_errors.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/util.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_pickles.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_scorer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_architectures.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/enable_gpu.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_models.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_cli.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_language.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_cli_app.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       copying spacy/tests/test_ty.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/package.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/benchmark_speed.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/debug_diff.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/pretrain.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/init_config.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/debug_data.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/init_pipeline.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/download.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/convert.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/profile.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/find_threshold.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/find_function.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/assemble.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/debug_config.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/validate.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/_util.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/train.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/evaluate.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/info.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/debug_model.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       copying spacy/cli/apply.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/lang
#       copying spacy/lang/char_classes.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/lang
#       copying spacy/lang/lex_attrs.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/lang
#       copying spacy/lang/punctuation.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/lang
#       copying spacy/lang/norm_exceptions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/lang
#       copying spacy/lang/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/lang
#       copying spacy/lang/tokenizer_exceptions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/lang
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/featureextractor.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/staticvectors.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/_precomputable_affine.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/tb_framework.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/_character_embed.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/callbacks.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/extract_spans.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/extract_ngrams.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/underscore.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/_serialize.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/_dict_proxies.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/legacy
#       copying spacy/pipeline/legacy/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/legacy
#       copying spacy/pipeline/legacy/entity_linker.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/legacy
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_edit_tree_internals
#       copying spacy/pipeline/_edit_tree_internals/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_edit_tree_internals
#       copying spacy/pipeline/_edit_tree_internals/schemas.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_edit_tree_internals
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/training/converters
#       copying spacy/training/converters/iob_to_docs.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training/converters
#       copying spacy/training/converters/conll_ner_to_docs.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training/converters
#       copying spacy/training/converters/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training/converters
#       copying spacy/training/converters/conllu_to_docs.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training/converters
#       copying spacy/training/converters/json_to_docs.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training/converters
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_tagger.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_morphologizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_senter.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_tok2vec.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_spancat.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_pipe_factories.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_analysis.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_span_finder.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_edit_tree_lemmatizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_entity_linker.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_entity_ruler.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_functions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_attributeruler.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_span_ruler.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_pipe_methods.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_models.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_lemmatizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_initialize.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_textcat.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_annotates_on_update.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       copying spacy/tests/pipeline/test_sentencizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/pipeline
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       copying spacy/tests/tokenizer/test_naughty_strings.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       copying spacy/tests/tokenizer/test_whitespace.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       copying spacy/tests/tokenizer/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       copying spacy/tests/tokenizer/test_exceptions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       copying spacy/tests/tokenizer/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       copying spacy/tests/tokenizer/test_explain.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       copying spacy/tests/tokenizer/test_urls.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/test_readers.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/test_new_example.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/test_rehearse.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/test_pretraining.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/test_corpus.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/test_augmenters.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/test_training.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       copying spacy/tests/training/test_logger.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/training
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_language.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_pipeline.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_vocab_strings.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_resource_warning.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_kb.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_extension_attrs.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_span_groups.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_docbin.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_doc.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       copying spacy/tests/serialize/test_serialize_config.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/serialize
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_nn_beam.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_neural_parser.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_parse.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_preset_sbd.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_add_label.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_state.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_parse_navigate.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_space_attachment.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_arc_eager_oracle.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_ner.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       copying spacy/tests/parser/test_nonproj.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/parser
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/matcher
#       copying spacy/tests/matcher/test_matcher_logic.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/matcher
#       copying spacy/tests/matcher/test_dependency_matcher.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/matcher
#       copying spacy/tests/matcher/test_matcher_api.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/matcher
#       copying spacy/tests/matcher/test_phrase_matcher.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/matcher
#       copying spacy/tests/matcher/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/matcher
#       copying spacy/tests/matcher/test_pattern_validation.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/matcher
#       copying spacy/tests/matcher/test_levenshtein.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/matcher
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang
#       copying spacy/tests/lang/test_attrs.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang
#       copying spacy/tests/lang/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang
#       copying spacy/tests/lang/test_lemmatizers.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang
#       copying spacy/tests/lang/test_initialize.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       copying spacy/tests/vocab_vectors/test_vectors.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       copying spacy/tests/vocab_vectors/test_lookups.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       copying spacy/tests/vocab_vectors/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       copying spacy/tests/vocab_vectors/test_memory_zone.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       copying spacy/tests/vocab_vectors/test_stringstore.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       copying spacy/tests/vocab_vectors/test_vocab_api.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       copying spacy/tests/vocab_vectors/test_similarity.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       copying spacy/tests/vocab_vectors/test_lexeme.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/vocab_vectors
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_add_entities.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_pickle_doc.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_retokenize_merge.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_array.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_span_group.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_creation.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_underscore.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_doc_api.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_token_api.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_morphanalysis.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_retokenize_split.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_span.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_graph.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       copying spacy/tests/doc/test_json_doc_conversion.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/doc
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/morphology
#       copying spacy/tests/morphology/test_morph_pickle.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/morphology
#       copying spacy/tests/morphology/test_morph_converters.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/morphology
#       copying spacy/tests/morphology/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/morphology
#       copying spacy/tests/morphology/test_morph_features.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/morphology
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/package
#       copying spacy/tests/package/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/package
#       copying spacy/tests/package/test_requirements.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/package
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sl
#       copying spacy/tests/lang/sl/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sl
#       copying spacy/tests/lang/sl/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sl
#       copying spacy/tests/lang/sl/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sl
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sk
#       copying spacy/tests/lang/sk/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sk
#       copying spacy/tests/lang/sk/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sk
#       copying spacy/tests/lang/sk/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sk
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ur
#       copying spacy/tests/lang/ur/test_prefix_suffix_infix.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ur
#       copying spacy/tests/lang/ur/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ur
#       copying spacy/tests/lang/ur/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ur
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/kmr
#       copying spacy/tests/lang/kmr/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/kmr
#       copying spacy/tests/lang/kmr/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/kmr
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/pl
#       copying spacy/tests/lang/pl/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/pl
#       copying spacy/tests/lang/pl/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/pl
#       copying spacy/tests/lang/pl/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/pl
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/vi
#       copying spacy/tests/lang/vi/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/vi
#       copying spacy/tests/lang/vi/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/vi
#       copying spacy/tests/lang/vi/test_serialize.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/vi
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sq
#       copying spacy/tests/lang/sq/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sq
#       copying spacy/tests/lang/sq/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sq
#       copying spacy/tests/lang/sq/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sq
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sv
#       copying spacy/tests/lang/sv/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sv
#       copying spacy/tests/lang/sv/test_prefix_suffix_infix.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sv
#       copying spacy/tests/lang/sv/test_exceptions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sv
#       copying spacy/tests/lang/sv/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sv
#       copying spacy/tests/lang/sv/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sv
#       copying spacy/tests/lang/sv/test_noun_chunks.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sv
#       copying spacy/tests/lang/sv/test_lex_attrs.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sv
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ga
#       copying spacy/tests/lang/ga/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ga
#       copying spacy/tests/lang/ga/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ga
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/he
#       copying spacy/tests/lang/he/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/he
#       copying spacy/tests/lang/he/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/he
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ms
#       copying spacy/tests/lang/ms/test_prefix_suffix_infix.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ms
#       copying spacy/tests/lang/ms/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ms
#       copying spacy/tests/lang/ms/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ms
#       copying spacy/tests/lang/ms/test_noun_chunks.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ms
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/hy
#       copying spacy/tests/lang/hy/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/hy
#       copying spacy/tests/lang/hy/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/hy
#       copying spacy/tests/lang/hy/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/hy
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/am
#       copying spacy/tests/lang/am/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/am
#       copying spacy/tests/lang/am/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/am
#       copying spacy/tests/lang/am/test_exception.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/am
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/nn
#       copying spacy/tests/lang/nn/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/nn
#       copying spacy/tests/lang/nn/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/nn
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/da
#       copying spacy/tests/lang/da/test_prefix_suffix_infix.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/da
#       copying spacy/tests/lang/da/test_exceptions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/da
#       copying spacy/tests/lang/da/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/da
#       copying spacy/tests/lang/da/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/da
#       copying spacy/tests/lang/da/test_noun_chunks.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/da
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ky
#       copying spacy/tests/lang/ky/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ky
#       copying spacy/tests/lang/ky/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ky
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/gu
#       copying spacy/tests/lang/gu/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/gu
#       copying spacy/tests/lang/gu/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/gu
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/grc
#       copying spacy/tests/lang/grc/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/grc
#       copying spacy/tests/lang/grc/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/grc
#       copying spacy/tests/lang/grc/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/grc
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ja
#       copying spacy/tests/lang/ja/test_morphologizer_factory.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ja
#       copying spacy/tests/lang/ja/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ja
#       copying spacy/tests/lang/ja/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ja
#       copying spacy/tests/lang/ja/test_serialize.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ja
#       copying spacy/tests/lang/ja/test_lemmatization.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ja
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/el
#       copying spacy/tests/lang/el/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/el
#       copying spacy/tests/lang/el/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/el
#       copying spacy/tests/lang/el/test_exception.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/el
#       copying spacy/tests/lang/el/test_noun_chunks.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/el
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lv
#       copying spacy/tests/lang/lv/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lv
#       copying spacy/tests/lang/lv/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lv
#       copying spacy/tests/lang/lv/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lv
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lb
#       copying spacy/tests/lang/lb/test_prefix_suffix_infix.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lb
#       copying spacy/tests/lang/lb/test_exceptions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lb
#       copying spacy/tests/lang/lb/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lb
#       copying spacy/tests/lang/lb/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/lb
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/it
#       copying spacy/tests/lang/it/test_stopwords.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/it
#       copying spacy/tests/lang/it/test_prefix_suffix_infix.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/it
#       copying spacy/tests/lang/it/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/it
#       copying spacy/tests/lang/it/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/it
#       copying spacy/tests/lang/it/test_noun_chunks.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/it
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ca
#       copying spacy/tests/lang/ca/test_prefix_suffix_infix.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ca
#       copying spacy/tests/lang/ca/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ca
#       copying spacy/tests/lang/ca/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ca
#       copying spacy/tests/lang/ca/test_exception.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ca
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/is
#       copying spacy/tests/lang/is/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/is
#       copying spacy/tests/lang/is/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/is
#       copying spacy/tests/lang/is/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/is
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/cs
#       copying spacy/tests/lang/cs/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/cs
#       copying spacy/tests/lang/cs/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/cs
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ru
#       copying spacy/tests/lang/ru/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ru
#       copying spacy/tests/lang/ru/test_exceptions.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ru
#       copying spacy/tests/lang/ru/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ru
#       copying spacy/tests/lang/ru/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ru
#       copying spacy/tests/lang/ru/test_lemmatizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ru
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/tl
#       copying spacy/tests/lang/tl/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/tl
#       copying spacy/tests/lang/tl/test_indices.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/tl
#       copying spacy/tests/lang/tl/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/tl
#       copying spacy/tests/lang/tl/test_punct.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/tl
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ro
#       copying spacy/tests/lang/ro/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ro
#       copying spacy/tests/lang/ro/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/ro
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/hsb
#       copying spacy/tests/lang/hsb/test_tokenizer.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/hsb
#       copying spacy/tests/lang/hsb/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/hsb
#       copying spacy/tests/lang/hsb/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/hsb
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/yo
#       copying spacy/tests/lang/yo/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/yo
#       copying spacy/tests/lang/yo/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/yo
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sa
#       copying spacy/tests/lang/sa/__init__.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sa
#       copying spacy/tests/lang/sa/test_text.py -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/lang/sa
# ...
#       copying spacy/vectors.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/vocab.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/vocab.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/vocab.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy
#       copying spacy/pipeline/dep_parser.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/morphologizer.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/multitask.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/ner.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/pipe.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/pipe.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/pipe.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/sentencizer.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/senter.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/tagger.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/trainable_pipe.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/trainable_pipe.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/transition_parser.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/pipeline/transition_parser.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline
#       copying spacy/kb/candidate.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/kb
#       copying spacy/kb/candidate.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/kb
#       copying spacy/kb/kb.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/kb
#       copying spacy/kb/kb.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/kb
#       copying spacy/kb/kb_in_memory.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/kb
#       copying spacy/kb/kb_in_memory.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/kb
#       copying spacy/training/__init__.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/align.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/alignment_array.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/alignment_array.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/example.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/example.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/example.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       copying spacy/training/gold_io.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/training
#       creating build/lib.macosx-15.0-arm64-cpython-313/spacy/cli/templates
#       copying spacy/cli/templates/quickstart_training.jinja -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli/templates
#       copying spacy/cli/templates/quickstart_training_recommendations.yml -> build/lib.macosx-15.0-arm64-cpython-313/spacy/cli/templates
#       copying spacy/matcher/dependencymatcher.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/dependencymatcher.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/levenshtein.c -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/levenshtein.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/matcher.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/matcher.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/matcher.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/phrasematcher.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/phrasematcher.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/phrasematcher.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/matcher/polyleven.c -> build/lib.macosx-15.0-arm64-cpython-313/spacy/matcher
#       copying spacy/ml/parser_model.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/ml/parser_model.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/ml
#       copying spacy/tokens/__init__.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/_retokenize.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/_retokenize.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/doc.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/doc.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/doc.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/graph.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/graph.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/morphanalysis.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/morphanalysis.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/morphanalysis.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/span.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/span.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/span.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/span_group.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/span_group.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/span_group.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/token.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/token.pyi -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/tokens/token.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tokens
#       copying spacy/pipeline/_parser_internals/__init__.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/_beam_utils.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/_beam_utils.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/_state.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/_state.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/arc_eager.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/arc_eager.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/ner.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/ner.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/nonproj.hh -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/nonproj.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/nonproj.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/stateclass.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/stateclass.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/transition_system.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_parser_internals/transition_system.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_parser_internals
#       copying spacy/pipeline/_edit_tree_internals/edit_trees.pxd -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_edit_tree_internals
#       copying spacy/pipeline/_edit_tree_internals/edit_trees.pyx -> build/lib.macosx-15.0-arm64-cpython-313/spacy/pipeline/_edit_tree_internals
#       copying spacy/tests/tokenizer/sun.txt -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/tokenizer
#       copying spacy/tests/package/pyproject.toml -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/package
#       copying spacy/tests/package/requirements.txt -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/package
#       copying spacy/tests/package/setup.cfg -> build/lib.macosx-15.0-arm64-cpython-313/spacy/tests/package
#       copying spacy/lang/sr/lemma_lookup_licence.txt -> build/lib.macosx-15.0-arm64-cpython-313/spacy/lang/sr
#       copying spacy/lang/hr/lemma_lookup_license.txt -> build/lib.macosx-15.0-arm64-cpython-313/spacy/lang/hr
#       running build_ext
#       building 'spacy.matcher.levenshtein' extension
#       creating build/temp.macosx-15.0-arm64-cpython-313/spacy/matcher
#       clang -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -Ispacy/matcher -I/private/var/folders/8k/h6dlr8g14r1952jl8tmfcpc40000gn/T/pip-build-env-lzxe3io4/overlay/lib/python3.13/site-packages/numpy/_core/include -I/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/include/python3.13 -I/opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/include -I/opt/homebrew/opt/python@3.13/Frameworks/Python.framework/Versions/3.13/include/python3.13 -c spacy/matcher/levenshtein.c -o build/temp.macosx-15.0-arm64-cpython-313/spacy/matcher/levenshtein.o -O2 -Wno-strict-prototypes -Wno-unused-function
#       spacy/matcher/levenshtein.c:855:59: warning: 'Py_UNICODE' is deprecated [-Wdeprecated-declarations]
#         855 | static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u) {
#             |                                                           ^
#       /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/include/python3.13/cpython/unicodeobject.h:10:1: note: 'Py_UNICODE' has been explicitly marked deprecated here
#          10 | Py_DEPRECATED(3.13) typedef wchar_t Py_UNICODE;
#             | ^
#       /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/include/python3.13/pyport.h:251:54: note: expanded from macro 'Py_DEPRECATED'
#         251 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#             |                                                      ^
#       spacy/matcher/levenshtein.c:856:11: warning: 'Py_UNICODE' is deprecated [-Wdeprecated-declarations]
#         856 |     const Py_UNICODE *u_end = u;
#             |           ^
#       /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/include/python3.13/cpython/unicodeobject.h:10:1: note: 'Py_UNICODE' has been explicitly marked deprecated here
#          10 | Py_DEPRECATED(3.13) typedef wchar_t Py_UNICODE;
#             | ^
#       /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/include/python3.13/pyport.h:251:54: note: expanded from macro 'Py_DEPRECATED'
#         251 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#             |                                                      ^
#       spacy/matcher/levenshtein.c:4516:70: error: too few arguments to function call, expected 6, have 5
#        4514 |                 int ret = _PyLong_AsByteArray((PyLongObject *)v,
#             |                           ~~~~~~~~~~~~~~~~~~~
#        4515 |                                               bytes, sizeof(val),
#        4516 |                                               is_little, !is_unsigned);
#             |                                                                      ^
#       /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/include/python3.13/cpython/longobject.h:111:17: note: '_PyLong_AsByteArray' declared here
#         111 | PyAPI_FUNC(int) _PyLong_AsByteArray(PyLongObject* v,
#             |                 ^                   ~~~~~~~~~~~~~~~~
#         112 |     unsigned char* bytes, size_t n,
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#         113 |     int little_endian, int is_signed, int with_exceptions);
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       spacy/matcher/levenshtein.c:4788:70: error: too few arguments to function call, expected 6, have 5
#        4786 |                 int ret = _PyLong_AsByteArray((PyLongObject *)v,
#             |                           ~~~~~~~~~~~~~~~~~~~
#        4787 |                                               bytes, sizeof(val),
#        4788 |                                               is_little, !is_unsigned);
#             |                                                                      ^
#       /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/include/python3.13/cpython/longobject.h:111:17: note: '_PyLong_AsByteArray' declared here
#         111 | PyAPI_FUNC(int) _PyLong_AsByteArray(PyLongObject* v,
#             |                 ^                   ~~~~~~~~~~~~~~~~
#         112 |     unsigned char* bytes, size_t n,
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#         113 |     int little_endian, int is_signed, int with_exceptions);
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       spacy/matcher/levenshtein.c:4984:70: error: too few arguments to function call, expected 6, have 5
#        4982 |                 int ret = _PyLong_AsByteArray((PyLongObject *)v,
#             |                           ~~~~~~~~~~~~~~~~~~~
#        4983 |                                               bytes, sizeof(val),
#        4984 |                                               is_little, !is_unsigned);
#             |                                                                      ^
#       /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/include/python3.13/cpython/longobject.h:111:17: note: '_PyLong_AsByteArray' declared here
#         111 | PyAPI_FUNC(int) _PyLong_AsByteArray(PyLongObject* v,
#             |                 ^                   ~~~~~~~~~~~~~~~~
#         112 |     unsigned char* bytes, size_t n,
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#         113 |     int little_endian, int is_signed, int with_exceptions);
#             |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       2 warnings and 3 errors generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for spacy
# Failed to build spacy
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (spacy)
# Note: you may need to restart the kernel to use updated packages.

# %%
nlp = spacy.cli.download("en_core_web_lg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nlp = spacy.cli.download("en_core_web_lg")
#
# NameError: name 'spacy' is not defined

# %%
import spacy
# Out:
# Traceback (most recent call last):
#
#   File /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3549 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[13], line 1
#     import spacy
#
#   File ~/Documents/github/DIGIT210/spacy/spacy.py:10
#     wordList = []
#     ^
# IndentationError: expected an indented block after function definition on line 9

# %%
import nltk
from nltk.corpus import wordnet as wn

# %%
o = open("grimm.txt", "w")
for r in ranked:
    o.write(str(r) + "\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 o = open("grimm.txt", "w")
# ----> 2 for r in ranked:
#       3     o.write(str(r) + "\n")
#
# NameError: name 'ranked' is not defined

# %%
import spacy
# Out:
# Traceback (most recent call last):
#
#   File /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3549 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 1
#     import spacy
#
#   File ~/Documents/github/DIGIT210/spacy/spacy.py:10
#     wordList = []
#     ^
# IndentationError: expected an indented block after function definition on line 9

# %%
import nltk

# %%
def wordCollector(words):
    wordList = []
    count = 0
    for token in words:
        if token.pos_ == "VERB":
            count += 1
            # print(count, ": ", token.text, " lemma: ", token.lemma_, " pos: ", token.pos_)
            # don't forget the underscore after token.lemma_ , token.pos_, etc.!
            wordList.append(token.lemma_)
            # print(count, ": ", token, token.pos_)
    # print(count, ": ", adjectives)
    return wordList
myWords = wordCollector(spacyRead)
print(myWords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 13
#      10             # print(count, ": ", token, token.pos_)
#      11     # print(count, ": ", adjectives)
#      12     return wordList
# ---> 13 myWords = wordCollector(spacyRead)
#      14 print(myWords)
#
# NameError: name 'spacyRead' is not defined

# %%
import spacy
# Out:
# Traceback (most recent call last):
#
#   File /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3549 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[7], line 1
#     import spacy
#
#   File ~/Documents/github/DIGIT210/spacy/spacy.py:10
#     wordList = []
#     ^
# IndentationError: expected an indented block after function definition on line 9
