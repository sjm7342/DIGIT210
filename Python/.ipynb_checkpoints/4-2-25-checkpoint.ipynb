# %%
import nltk
import nltk.corpus
# The next line downloads all the example texts used in the NLTK book at https://www.nltk.org/book !
# You can comment out the download line after the first time you do it.
nltk.download('book')
from nltk.book import *
# The next line lets us do GET requests from remote URLs on the web:
from urllib import request
# The following import lines are for plotting interactive visualizations in Python
import matplotlib
import matplotlib.pyplot as plt
import tk
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/seanmartin/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection book
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot(range(10))
plt.show()

# %%
### See how these words are dispersed in NLTK text 1 (Moby Dick)
words = ["whale", "sea", "ship", "captain"]
nltk.draw.dispersion_plot(text1, words)
plt.show()

# %%
# Another dispersion plot written closer to the NLTK example:
# Choose the text first (text 4 is Inaugural Addresses):
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])
plt.show()

# %%
text6.common_contexts(["find","seek"])
# Out:
# to_the you_the

# %%
text6.similar('grail')
# Out:
# britons same rabbit lord system nose forest curtains questions scene
# who saxons one land what coconuts two husk air cart

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text) * 100 
    # ebb: I'm just  multipling by 100 to yield this as a percentage value

montyPython = lexical_diversity(text6)  
mobyDick = lexical_diversity(text3)

print(f"montyPython = {montyPython}")
print(f"mobyDick = {mobyDick}")
# Out:
# montyPython = 12.76595744680851
# mobyDick = 6.230453042623537

# %%
# Blithedale Romance text file on Project Gutenberg
bookurl= "https://www.gutenberg.org/cache/epub/2081/pg2081.txt"
response = request.urlopen(bookurl)
br = response.read().decode('utf8')
type(br)
print(len(br))
# make a variable
howLong = len(br)
# picture string version! 
print(f"howLong = {howLong}")
novelSlice = br[:500]
print(f"novelSlice = {novelSlice}")

# splitEmUp = br.split()
# print(f"splitEmUp = {splitEmUp}")

for token in splitEmUp:
    if token.endswith('ing'):
        print(token)
# Out:
# 464044
# howLong = 464044
# novelSlice = ﻿The Project Gutenberg eBook of The Blithedale Romance
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using t
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 17
#      12 print(f"novelSlice = {novelSlice}")
#      14 # splitEmUp = br.split()
#      15 # print(f"splitEmUp = {splitEmUp}")
# ---> 17 for token in splitEmUp:
#      18     if token.endswith('ing'):
#      19         print(token)
#
# NameError: name 'splitEmUp' is not defined

# %%
# Blithedale Romance text file on Project Gutenberg
bookurl= "https://www.gutenberg.org/cache/epub/2081/pg2081.txt"
response = request.urlopen(bookurl)
br = response.read().decode('utf8')
type(br)
print(len(br))
# make a variable
howLong = len(br)
# picture string version! 
print(f"howLong = {howLong}")
novelSlice = br[:500]
print(f"novelSlice = {novelSlice}")

# splitEmUp = br.split()
# print(f"splitEmUp = {splitEmUp}")

for token in splitEmUp:
    if token.endswith('ing'):
        print(token)
# Out:
# 464044
# howLong = 464044
# novelSlice = ﻿The Project Gutenberg eBook of The Blithedale Romance
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using t
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 17
#      12 print(f"novelSlice = {novelSlice}")
#      14 # splitEmUp = br.split()
#      15 # print(f"splitEmUp = {splitEmUp}")
# ---> 17 for token in splitEmUp:
#      18     if token.endswith('ing'):
#      19         print(token)
#
# NameError: name 'splitEmUp' is not defined

# %%
concordance = nltk.Text(splitEmUp).concordance("living")
print(f"concordance = {concordance}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 concordance = nltk.Text(splitEmUp).concordance("living")
#       2 print(f"concordance = {concordance}")
#
# NameError: name 'splitEmUp' is not defined

# %%
from nltk.corpus import inaugural
inaugural.fileids()
cfd = nltk.ConditionalFreqDist(
    (target,fileid[:4])
    for fileid in inaugural.fileids()
    # I added the next line to help make the plot more legible!
    if int(fileid[:4]) > 1990
    for w in inaugural.words(fileid)
    for target in ['america', 'citizen']
    if w.lower().startswith(target))
cfd.plot()
plt.show()

# %%
# Blithedale Romance text file on Project Gutenberg
bookurl= "https://www.gutenberg.org/cache/epub/2081/pg2081.txt"
response = request.urlopen(bookurl)
br = response.read().decode('utf8')
type(br)
print(len(br))
# make a variable
howLong = len(br)
# picture string version! 
print(f"howLong = {howLong}")
novelSlice = br[:500]
print(f"novelSlice = {novelSlice}")

splitEmUp = br.split()
print(f"splitEmUp = {splitEmUp}")

for token in splitEmUp:
    if token.endswith('ing'):
        print(token)
# Out:
# 464044
# howLong = 464044
# novelSlice = ﻿The Project Gutenberg eBook of The Blithedale Romance
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using t
# splitEmUp = ['\ufeffThe', 'Project', 'Gutenberg', 'eBook', 'of', 'The', 'Blithedale', 'Romance', 'This', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever.', 'You', 'may', 'copy', 'it,', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'www.gutenberg.org.', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States,', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'eBook.', 'Title:', 'The', 'Blithedale', 'Romance', 'Author:', 'Nathaniel', 'Hawthorne', 'Release', 'date:', 'February', '1,', '2000', '[eBook', '#2081]', 'Most', 'recently', 'updated:', 'December', '31,', '2020', 'Language:', 'English', 'Credits:', 'Produced', 'by', 'Michael', 'Pullen', 'and', 'Tom', 'Gannett.', 'HTML', 'version', 'by', 'Al', 'Haines.', '***', 'START', 'OF', 'THE', 'PROJECT', 'GUTENBERG', 'EBOOK', 'THE', 'BLITHEDALE', 'ROMANCE', '***', 'Produced', 'by', 'Michael', 'Pullen', 'and', 'Tom', 'Gannett.', 'HTML', 'version', 'by', 'Al', 'Haines.', 'The', 'Blithedale', 'Romance', 'by', 'Nathaniel', 'Hawthorne', 'Table', 'of', 'Contents', 'I.', 'OLD', 'MOODIE', 'II.', 'BLITHEDALE', 'III.', 'A', 'KNOT', 'OF', 'DREAMERS', 'IV.', 'THE', 'SUPPER-TABLE', 'V.', 'UNTIL', 'BEDTIME', 'VI.', "COVERDALE'S", 'SICK', 'CHAMBER', 'VII.', 'THE', 'CONVALESCENT', 'VIII.', 'A', 'MODERN', 'ARCADIA', 'IX.', 'HOLLINGSWORTH,', 'ZENOBIA,', 'PRISCILLA', 'X.', 'A', 'VISITOR', 'FROM', 'TOWN', 'XI.', 'THE', 'WOOD-PATH', 'XII.', "COVERDALE'S", 'HERMITAGE', 'XIII.', "ZENOBIA'S", 'LEGEND', 'XIV.', "ELIOT'S", 'PULPIT', 'XV.', 'A', 'CRISIS', 'XVI.', 'LEAVE-TAKINGS', 'XVII.', 'THE', 'HOTEL', 'XVIII.', 'THE', 'BOARDING-HOUSE', 'XIX.', "ZENOBIA'S", 'DRAWING-ROOM', 'XX.', 'THEY', 'VANISH', 'XXI.', 'AN', 'OLD', 'ACQUAINTANCE', 'XXII.', 'FAUNTLEROY', 'XXIII.', 'A', 'VILLAGE', 'HALL', 'XXIV.', 'THE', 'MASQUERADERS', 'XXV.', 'THE', 'THREE', 'TOGETHER', 'XXVI.', 'ZENOBIA', 'AND', 'COVERDALE', 'XXVII.', 'MIDNIGHT', 'XXVIII.', 'BLITHEDALE', 'PASTURE', 'XXIX.', 'MILES', "COVERDALE'S", 'CONFESSION', 'I.', 'OLD', 'MOODIE', 'The', 'evening', 'before', 'my', 'departure', 'for', 'Blithedale,', 'I', 'was', 'returning', 'to', 'my', 'bachelor', 'apartments,', 'after', 'attending', 'the', 'wonderful', 'exhibition', 'of', 'the', 'Veiled', 'Lady,', 'when', 'an', 'elderly', 'man', 'of', 'rather', 'shabby', 'appearance', 'met', 'me', 'in', 'an', 'obscure', 'part', 'of', 'the', 'street.', '"Mr.', 'Coverdale,"', 'said', 'he', 'softly,', '"can', 'I', 'speak', 'with', 'you', 'a', 'moment?"', 'As', 'I', 'have', 'casually', 'alluded', 'to', 'the', 'Veiled', 'Lady,', 'it', 'may', 'not', 'be', 'amiss', 'to', 'mention,', 'for', 'the', 'benefit', 'of', 'such', 'of', 'my', 'readers', 'as', 'are', 'unacquainted', 'with', 'her', 'now', 'forgotten', 'celebrity,', 'that', 'she', 'was', 'a', 'phenomenon', 'in', 'the', 'mesmeric', 'line;', 'one', 'of', 'the', 'earliest', 'that', 'had', 'indicated', 'the', 'birth', 'of', 'a', 'new', 'science,', 'or', 'the', 'revival', 'of', 'an', 'old', 'humbug.', 'Since', 'those', 'times', 'her', 'sisterhood', 'have', 'grown', 'too', 'numerous', 'to', 'attract', 'much', 'individual', 'notice;', 'nor,', 'in', 'fact,', 'has', 'any', 'one', 'of', 'them', 'come', 'before', 'the', 'public', 'under', 'such', 'skilfully', 'contrived', 'circumstances', 'of', 'stage', 'effect', 'as', 'those', 'which', 'at', 'once', 'mystified', 'and', 'illuminated', 'the', 'remarkable', 'performances', 'of', 'the', 'lady', 'in', 'question.', 'Nowadays,', 'in', 'the', 'management', 'of', 'his', '"subject,"', '"clairvoyant,"', 'or', '"medium,"', 'the', 'exhibitor', 'affects', 'the', 'simplicity', 'and', 'openness', 'of', 'sc ...
# using
# evening
# returning
# attending
# falling
# unfolding
# turning
# trying
# repeating
# hesitating
# going
# something
# standing
# revealing
# getting
# wondering
# involving
# going
# retaining
# stopping
# Arriving
# nothing
# drinking
# setting
# getting
# roaring
# inspiring
# deluding
# spreading
# beginning
# morning
# partaking
# whitening
# puffing
# burning
# being
# going
# quitting
# flinging
# travelling
# drifting
# coming
# alighting
# riding
# burning
# encountering
# unmuffling
# listening
# unflagging
# beginning
# melting
# awaiting
# contrasting
# smiling
# looking
# knowing
# something
# something
# exercising
# relinquishing
# something
# going
# lead,--something
# twittering
# singing
# taking
# enduring
# knitting
# gleaming
# adopting
# sweeping
# shivering
# something
# creating
# scorning
# being
# breathing
# declining
# bringing
# heaping
# stamping
# foddering
# speaking
# wishing
# intermingling
# fast-descending
# evening
# trailing
# rustling
# blazing
# enervating
# showing
# striving
# laboring
# performing
# wresting
# filching
# winning
# crumbling
# raising
# reckoning
# self-seeking
# getting
# Constituting
# dawning
# Looking
# perceiving
# being
# making
# drifting
# being
# harping
# bubbling
# crumbling
# burning
# bouncing
# something
# laboring
# being
# regaining
# putting
# striving
# sitting
# during
# blazing
# nothing
# encouraging
# contrasting
# thinking
# putting
# stepping
# rather,--judging
# entering
# remaining
# taking
# looking
# glancing
# standing
# falling
# betokening
# vibrating
# being
# doing
# anything
# Recollecting
# fixing
# nothing
# doing
# Meeting
# striking
# befitting
# meaning
# willing
# anything
# recovering
# anything
# thing
# smiling
# choosing
# shivering
# shivering
# pouring
# gulping
# helping
# dropping
# using
# perpetrating
# behaving
# Being
# milking
# "something
# shoemaking
# keeping
# footing
# stocking
# stocking
# making
# looking
# climbing
# accounting
# supposing
# being
# nothing
# believe,--nothing
# anything
# happening
# startling
# gazing
# running
# tormenting
# caressing
# questioning
# Notwithstanding
# shrieking
# pressing
# neighboring
# glimmering
# perpetrating
# examining
# providing
# communicating
# acknowledging
# calling
# being
# reconsidering
# finding
# anything
# being
# evening
# evening
# shivering
# growing
# During
# combining
# half-waking
# including
# Starting
# shining
# shimmering
# passing
# vanishing
# reappearing
# sleep-dispelling
# creaking
# being
# compelling
# cursing
# preceding
# intermeddling
# morning
# king
# evening
# boiling
# shivering
# extruding
# having
# being
# something
# treading
# going
# nothing
# nothing
# "nothing
# helping
# dying
# mortifying
# mending
# according
# oversetting
# scattering
# wronging
# coloring
# preceding
# adorning
# something
# "Nothing
# being
# laughing
# taking
# anything
# imputing
# coming
# nothing
# holding
# understanding
# reaching
# wasting
# during
# something
# blooming
# watching
# mixing
# favoring
# seeking
# challenging
# nothing
# closing
# laughing
# intoxicating
# introducing
# containing
# implying
# doing
# taking
# nothing
# accompanying
# stealing
# pausing
# holding
# ascending
# babbling
# being
# during
# doing
# wearing
# holding
# admiring
# waiting
# turning
# closing
# coexisting
# holding
# anything
# nothing
# Being
# during
# Agreeing
# illustrating
# asking
# introducing
# establishing
# something
# putting
# cunning
# fling
# floundering
# finishing
# "bellowing
# attempting
# estranging
# being
# conferring
# wasting
# considering
# nothing
# going
# pronouncing
# fiddling
# rendering
# sketching
# planning
# building
# being
# leaving
# treading
# gazing
# making
# bring
# admitting
# finding
# Arriving
# a-maying
# everlasting
# decking
# Being
# charming
# nothing
# surveying
# thing
# bringing
# something
# scrambling
# sipping
# discovering
# returning
# running
# appearing
# calling
# thing
# hearing
# giving
# shivering
# leaving
# Emerging
# wandering
# holding
# Being
# warning
# fling
# thwarting
# holding
# Returning
# seeking
# stamping
# holding
# Arriving
# uttering
# making
# lifting
# peeping
# going
# bring
# being
# during
# bring
# carrying
# keeping
# continuing
# wearing
# pausing
# sloping
# plaything
# pretending
# supporting
# flashing
# vanishing
# pillowing
# dropping
# causing
# being
# rustling
# flickering
# glorifying
# speaking
# fling
# nothing
# allowing
# feeling
# living
# beginning
# fling
# intercepting
# permitting
# gazing
# disapproving
# making
# stooping
# denying
# turning
# lifting
# shaking
# unquestioning
# taking
# attaining
# blessing
# unquestioning
# expecting
# everything
# intending
# wellspring
# overarching
# flitting
# impending
# declining
# tiding
# hastening
# looking
# comparing
# evening
# being
# walking
# thing
# engrossing
# leaving
# solacing
# bewitching
# thing
# supposing
# sterling
# meditating
# Arriving
# standing
# according
# lingering
# passing
# something
# looking
# beginning
# selecting
# according
# projecting
# questioning
# repairing
# sallying
# living
# lifting
# putting
# trying
# creeping
# smiling
# setting
# footing
# giving
# opening
# having
# appropriating
# fling
# uncalculating
# fling
# overthrowing
# beginning
# knitting
# damning
# nothing
# besetting
# persuading
# defending
# being
# will,--everything
# pulling
# nothing
# transmuting
# impelling
# addressing
# looking
# glowing
# bring
# getting
# gazing
# forcing
# conjecturing
# made,--taking
# opposing
# repairing
# deserting
# during
# losing
# going
# Everything
# anything
# feeling
# being
# betokening
# being
# rubbing
# Musing
# longing
# going
# offering
# Exploring
# taking
# coming
# fling
# deciding
# going
# having
# getting
# existing
# beginning
# everything
# becoming
# returning
# kissing
# pitying
# flickering
# leaving
# making
# treating
# fitting
# parting
# respecting
# foreboding
# everything
# looking
# parting
# Being
# chilling
# playing
# drawing
# Unclosing
# putting
# grunting
# Peeping
# giving
# hanging
# Arriving
# inclining
# sweeping
# amalgamating
# growing
# sojourning
# sitting
# combining
# writing
# surrounding
# bustling
# anything
# echoing
# ringing
# announcing
# lumbering
# neighboring
# scudding
# pervading
# announcing
# rushing
# during
# winding
# pounding
# sighing
# plunging
# inhaling
# absorbing
# keeping
# pointing
# spiteful-looking
# venturing
# getting
# pertaining
# promising
# blighting
# descending
# surrounding
# creeping
# descending
# gliding
# besieging
# Bewitching
# looking
# glittering
# examining
# standing
# brushing
# looking
# stealing
# laying
# belonging
# being
# curling
# serving
# nothing
# noticing
# looking
# nestling
# launching
# flying
# intervening
# looking
# preceding
# evening
# awakening
# leaving
# treading
# standing
# beholding
# peeping
# nothing
# dripping
# transporting
# something
# drifting
# succeeding
# unhumanizing
# nothing
# romping
# ceiling
# making
# directing
# something
# varying
# distinguishing
# looking
# insulating
# during
# something
# fling
# consummating
# pausing
# arraying
# presenting
# meaning
# during
# listening
# discussing
# displaying
# making
# detecting
# recognizing
# being
# drawing
# shooting
# intervening
# comprising
# letting
# meditating
# accounting
# letting
# taking
# bringing
# extenuating
# being
# effecting
# withdrawing
# making
# penetrating
# passing
# tormenting
# going
# recognizing
# nothing
# anything
# nothing
# taking
# being
# feeling
# conveying
# yielding
# anything
# flaming
# nothing
# imparting
# glowing
# adding
# revelling
# lacking
# opposing
# something
# something
# laughing
# flaming
# resenting
# fancying
# self-beginning
# self-ending
# "Nothing
# nothing
# being
# fling
# striving
# growing
# gnawing
# shivering
# Arriving
# shaking
# waiting
# offering
# lurking
# sitting
# approving
# wondering
# engrossing
# comparing
# retaining
# retiring
# pressing
# Settling
# nothing
# questioning
# thrilling
# impending
# recollecting
# living
# wandering
# appearing
# turning
# willing
# glittering
# endeavoring
# finding
# doing
# turning
# raising
# having
# seeing
# wondering
# something
# ballad,--anything
# discrowning
# abasing
# winning
# playing
# being
# expressing
# holding
# warming
# going
# lingering
# bidding
# foregoing
# hovering
# haunting
# coloring
# Starting
# shining
# finding
# sleeping
# standing
# turning
# prowling
# frightening
# making
# muttering
# yawning
# looking
# removing
# nothing
# finding
# leaving
# tending
# being
# addressing
# Setting
# bobbing
# bobbing
# getting
# groping
# anything
# having
# throwing
# lighting
# keeping
# having
# poking
# immersing
# setting
# making
# stabbing
# peering
# flowing
# devilish-looking
# ourselves,--searching
# giving
# Putting
# streaming
# gazing
# swaying
# Arriving
# choking
# bubbling
# never-ending
# flitting
# bring
# rising
# staring
# looking
# neighboring
# laying
# sterling
# Being
# fitting
# seeking
# wading
# nothing
# pause,--resting
# balancing
# whispering
# peering
# holding
# shaking
# taking
# sloping
# taking
# interpolating
# avoiding
# leaning
# bringing
# smothering
# Everything
# controlling
# nothing
# according
# bleeding
# dreading
# feeling
# being
# retaining
# being
# catching
# judging
# encountering
# unquestioning
# Drawing
# interpreting
# raising
# upbraiding
# flinging
# admitting
# ruling
# standing
# willing
# establishing
# suffering
# darkening
# laboring
# lapsing
# going
# being
# Being
# having
# notwithstanding
# dying
# something
# fling
# thing
# deepening
# thing
# foregoing
# understanding
# Creating
# paying
# copying
# distributing
# following
# including
# paying
# anything
# complying
# promoting
# using
# distributing
# Redistributing
# reading
# using
# using
# obtaining
# complying
# displaying
# creating
# promoting
# sharing
# keeping
# keeping
# distributing
# creating
# concerning
# following
# using
# indicating
# paying
# redistributing
# providing
# appearing
# beginning
# containing
# displaying
# including
# processing
# exporting
# obtaining
# copying
# distributing
# providing
# distributing
# using
# following
# writing
# writing
# creating
# distributing
# including
# receiving
# sending
# providing
# writing
# remaining
# providing
# including
# following
# including
# reaching
# ensuring
# increasing
# including
# maintaining
# complying
# regulating
# accepting
# concerning
# including
# including

# %%
concordance = nltk.Text(splitEmUp).concordance("living")
print(f"concordance = {concordance}")
# Out:
# Displaying 7 of 7 matches:
# his lady-love,--in short, we were a living epitome of defunct fashions, and th
# leafy shadow where he stood, like a living tip of fire. He carried a stick wit
# tural and immediate. It is with the living voice alone that she can compel the
# ne, and twenty other faces that are living now, shall be hung up; and as for m
# ke a gray kennel-rat than any other living thing, he began to take the aspect
# l me how all things were. The first living creature that I met was a partridge
# orcibly conscious of an intense and living pain there. Her glance, wandering w
# concordance = None

# %%
from nltk.corpus import inaugural
inaugural.fileids()
cfd = nltk.ConditionalFreqDist(
    (target,fileid[:4])
    for fileid in inaugural.fileids()
    # I added the next line to help make the plot more legible!
    if int(fileid[:4]) > 1990
    for w in inaugural.words(fileid)
    for target in ['america', 'citizen']
    if w.lower().startswith(target))
cfd.plot()
plt.show()
